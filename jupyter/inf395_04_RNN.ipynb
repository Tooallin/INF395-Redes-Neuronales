# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader

# %%
df = pd.read_csv("/content/IMDB-Dataset.csv")
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df['review'] = df['review'].str.lower().str.split()

df.head()
# Out:
#                                               review sentiment
# 0  [one, of, the, other, reviewers, has, mentione...  positive
# 1  [a, wonderful, little, production., <br, /><br...  positive
# 2  [i, thought, this, was, a, wonderful, way, to,...  positive
# 3  [basically, there's, a, family, where, a, litt...  negative
# 4  [petter, mattei's, "love, in, the, time, of, m...  positive

# %%
le = LabelEncoder()
df['sentiment'] = le.fit_transform(df['sentiment'])

train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)
df.head()
# Out:
#                                               review  sentiment
# 0  [one, of, the, other, reviewers, has, mentione...          1
# 1  [a, wonderful, little, production., <br, /><br...          1
# 2  [i, thought, this, was, a, wonderful, way, to,...          1
# 3  [basically, there's, a, family, where, a, litt...          0
# 4  [petter, mattei's, "love, in, the, time, of, m...          1

# %%
test_data.head()
# Out:
#                                                   review  sentiment
# 33553  [i, really, liked, this, summerslam, due, to, ...          1
# 9427   [not, many, television, shows, appeal, to, qui...          1
# 199    [the, film, quickly, gets, to, a, major, chase...          0
# 12447  [jane, austen, would, definitely, approve, of,...          1
# 39489  [expectations, were, somewhat, high, for, me, ...          0

# %%
vocab = {word for phrase in df['review'] for word in phrase}
word_to_idx = {word: idx for idx, word in enumerate(vocab, start=1)}

max_length = df['review'].str.len().max()
max_length
# Out:
# 2470

# %%
vocab
# Out:
# {'strawberry',
#  'bob!<br',
#  'audience_great',
#  'bullying.',
#  'g-man',
#  'scourge,',
#  'anansie',
#  '/>poo',
#  'jäniksen',
#  '(repetitious',
#  'borders!),',
#  'alien-costume',
#  'tawny',
#  'too...whoa!',
#  'multimillionaire',
#  'shielded',
#  'noblesse',
#  'simon?)',
#  'coast-meets-',
#  'process,"',
#  'governator',
#  'jokes,"',
#  'whatsoever...i',
#  'rendering,',
#  'offers.',
#  'zoos',
#  'nerf',
#  'main-writer',
#  "o'daniel.",
#  'pouting',
#  'al-mutairi"',
#  '(shirdi',
#  'loooooove',
#  '"extras."',
#  'complicit',
#  'loomis.<br',
#  '21.)<br',
#  'europe:',
#  'impassive',
#  '(useless)',
#  '"specialagentfoxmulder"',
#  'warnercolor',
#  '"little',
#  'stage).',
#  'wisecracks!)',
#  'others").',
#  'snooze-fests',
#  'objective;',
#  'hamburger.',
#  'preparations.',
#  'bookish.<br',
#  '"incidents"',
#  'co-ordinate',
#  '(1992).',
#  '/>wrong!',
#  'ziplock',
#  'killers!',
#  'story".<br',
#  'fabulous-',
#  'firmer".',
#  'firearms;',
#  'screamy',
#  'romeo&juliet',
#  'deesh".',
#  '200mph',
#  'pairs,',
#  'vidler',
#  "bert's",
#  'beaton)',
#  'stupified',
#  'gentle"',
#  "'must",
#  'interviewer:',
#  'depressing.but',
#  '"chemistry."',
#  'slasher/comic',
#  'bandit",',
#  'background")',
#  'employee?',
#  'matrix."<br',
#  'aunt?',
#  'indiscernible,',
#  "'over-act',",
#  'villains:5',
#  '1959-1973.',
#  'ape-hater',
#  'apanowicz',
#  'andrésen)',
#  'corman...',
#  'compulsion.',
#  '"vellai',
#  'akshaye-ayesha',
#  'decimals',
#  '"cardassian"',
#  '"parisian"',
#  'piglets',
#  'hopping',
#  'endings;',
#  'rainman',
#  'wide-screen,',
#  "mobster's",
#  'buzzard,',
#  'spider-web',
#  'superman.',
#  'kombat.',
#  'angst-driven',
#  "fairbanks's",
#  'alliteration.',
#  'suckfest.',
#  'umm..',
#  'tragedy)',
#  'better(as',
#  'paper,nick',
#  'bottom-to-mid',
#  "ellington's",
#  "want's",
#  'over-heard',
#  'either...they',
#  'wryness',
#  'dullllllllllll.',
#  'antecedent',
#  '"massa\'s',
#  'closeups)',
#  '36??',
#  'suggest--',
#  'liberal,',
#  'best..',
#  '(thats',
#  'window????',
#  'certification',
#  "caitlin's",
#  'askeys',
#  'testify',
#  'afterwards!!',
#  'chickens?"',
#  '/>grisby',
#  'cassanova',
#  'dweezil',
#  'absent.)',
#  'msrk',
#  'downstream,',
#  'kohli,',
#  'pocket',
#  'build-up',
#  'emily(joan',
#  '(hanzo',
#  "segment'",
#  '(duncan)',
#  'yum-yum.<br',
#  'soggy,',
#  'novel)',
#  'purposes--more',
#  'arte),',
#  'scab',
#  'admission.',
#  'likes:',
#  'points»',
#  'storeroom,',
#  'know?<br',
#  'pops".',
#  'inner-emotions',
#  'them--despite',
#  'tonik,',
#  '(waterbury,',
#  'naturally.',
#  '/>implausible',
#  'pre-ilm',
#  'trashman',
#  'wb-quality',
#  'doggies,',
#  'shining"---but',
#  'version-',
#  'smells,',
#  'reviewing',
#  'watson.',
#  'mcgregors',
#  'ab',
#  'hard-to-swallow',
#  '\'extraordinary."',
#  'licence',
#  'sheep',
#  'brake-dancing',
#  'chintzy.<br',
#  'somnolent',
#  '(tokoro',
#  'nr.6',
#  'cammareri',
#  'austrailan',
#  'interviewed..."',
#  'confrontations/fight',
#  '"hey...remember',
#  'rubric.<br',
#  '"nightbeast",',
#  'sexpot"',
#  '"died',
#  'binging',
#  'overstepping',
#  'movies...or',
#  'muckraking',
#  'midway.',
#  'heroin?',
#  'blain',
#  'nine-year-old,',
#  "shoot'n'run",
#  "snicket's",
#  '/>"boogie',
#  'character--so',
#  'bichunmoo',
#  'cubitt}',
#  "belgium's",
#  'roughest,',
#  'schleps',
#  "'everyone'",
#  'brimley,',
#  'restaraunt',
#  'woolf?"',
#  '("ooh',
#  '(absent)',
#  "jumbaa's",
#  "deceased--it's",
#  "away...don't",
#  'lines:',
#  'salted',
#  '8.50',
#  "'nanites'?",
#  'reminisce',
#  'ta,',
#  'maintains.',
#  'guðnason),',
#  'people-"psst,',
#  "verel's",
#  'sumo...',
#  'al-yusuf',
#  'mussolini',
#  'ex-con.',
#  'bwahahahahha.',
#  '"marshovia",',
#  'eludes',
#  "intentions',",
#  'sub-category',
#  'dakotas,',
#  'litel),',
#  'conceive',
#  'neat-freak',
#  '37),',
#  'underling',
#  'dealers.<br',
#  'patrons;funk',
#  'candy...which',
#  'altering.',
#  "/>cain's",
#  'falsification',
#  'fairly,',
#  '/>fade',
#  'however!),',
#  'tonks.',
#  'finnell',
#  'harlech',
#  'life!<br',
#  'tall").',
#  'metaphorical).',
#  "cardiff's",
#  'unenviable',
#  'day,"',
#  'hilarious.they',
#  'hemmitt',
#  'mogadon?',
#  'mob.',
#  'enjoy...bade',
#  'chip"',
#  'freshly-undead',
#  'cat!"',
#  'the...???english',
#  "continent'",
#  'turbocharger',
#  'abuse...did',
#  'eloquence.',
#  'attests.',
#  'circumstance',
#  'fresca"',
#  'celluloid-particularly',
#  'schroeder:',
#  'erections,',
#  '\x84comedy"',
#  'her?',
#  'planned:',
#  '/>benicio',
#  '/>shawn',
#  '$400.00.',
#  'dentist",',
#  '7/7',
#  'periods;',
#  'backwards...<br',
#  "character--he's",
#  'killjoy.<br',
#  'gore/death',
#  'pluses-',
#  'becky(jena',
#  '/>hero:',
#  '10-odd',
#  "dk's",
#  ',please!").<br',
#  'swimsuits',
#  'facility).',
#  'hughes),',
#  'comedy...but',
#  'honeymooners,"',
#  '(zlatorog',
#  'caricature?',
#  '"c+"',
#  'filming',
#  'breillat.',
#  'matter,',
#  "candidate'",
#  '*revenge',
#  'lotto',
#  'mishmashes,',
#  'park...errr...the',
#  'immemorial).<br',
#  'weakness--women.',
#  'shackled',
#  "kathleen's",
#  'gordon"',
#  'sense?',
#  'act...if',
#  'mustaches.',
#  'area;',
#  "danver's",
#  'coughlan.',
#  'un-appealing',
#  'legs',
#  'crocks',
#  '"s"',
#  '"cheers")',
#  'woodhouse..i',
#  'flapping.',
#  'roles.but',
#  'subsequently',
#  'irrelevancies,',
#  '(bates',
#  '"surrealist"',
#  'mateo,',
#  'guy/sci-fi',
#  '7",',
#  "'social'",
#  'over-the-top.',
#  'daniels).<br',
#  'scene-stealer',
#  '"gilda"',
#  'www.reel13.org)',
#  'coconut',
#  'multi-racial,',
#  'brutality-on-video,',
#  'daniela',
#  'continent"',
#  'opposite!',
#  'gorgous',
#  'colagrande',
#  'funnier!',
#  'strada.',
#  'davies,',
#  'saveles:',
#  'illness?',
#  'rampage,"',
#  'it.all',
#  'self-importance.<br',
#  'resurrection",',
#  'revolutionary,',
#  'scarf/pashmina/shawl',
#  'neo-film',
#  'sleazo',
#  '"outbreak"},',
#  'scratched-up',
#  't"--seriously,',
#  'wanted-',
#  'racist)',
#  'grave.<br',
#  'simms,',
#  'dumb).',
#  'zandalee',
#  'apostoles?',
#  "rostov's",
#  'search.',
#  'homosexual.<br',
#  '(granted',
#  'brandon,',
#  'well-to-do',
#  'this....the',
#  '"highlands',
#  'khanna.its',
#  'cylinder!"',
#  '2gether!',
#  '1/2/',
#  'okuhara',
#  'society",',
#  'railed',
#  '"bay',
#  'embezzled',
#  'always-lovely',
#  '[xizhao]',
#  'cast/extras',
#  'approximately',
#  'contextual',
#  "movie''don't",
#  'scar.',
#  'sereia',
#  'comic-relief',
#  'sick--like',
#  'jowly)',
#  'assignment.',
#  'horrifying.',
#  'merkurjev,',
#  'pro-americanism',
#  "'clever",
#  'bomfunk',
#  '(wether',
#  'feathers:',
#  'aesthetical',
#  'happens.jokes',
#  '/>michelle',
#  "'seance'",
#  'feedback.',
#  "powell/pressburger's",
#  'grave!)',
#  'rip-offs;',
#  'murders),',
#  'partners?',
#  'decided-upon',
#  '(ctrl+c,',
#  'fun/good',
#  'hardcores.',
#  'english-speaking',
#  'brite',
#  'backfires,',
#  'confined.<br',
#  'blue-green',
#  'lilt',
#  'hammer).',
#  'begotten"',
#  'yesteryear',
#  '^-^<br',
#  'calls)',
#  'pocatello,',
#  'piston',
#  'tian.',
#  'nasal',
#  '"zatoichi"',
#  'penguins)',
#  'rotation,',
#  'highlands',
#  'brown(homecoming',
#  '1938);',
#  'undercurrent',
#  'elsie',
#  'graham),',
#  '("rocky',
#  '/>(ok,',
#  'unknowns.',
#  'pretendeous',
#  'bertin).',
#  'pacula).',
#  "pupil')",
#  'quivering.',
#  'since--and',
#  '(luckly',
#  'f@#$',
#  'junked',
#  'race).',
#  "'gremlins'.",
#  '1974).',
#  'exchange',
#  '"asylum',
#  'better--than',
#  'waffle..',
#  'girlfriend),',
#  'manhunt',
#  "`love'",
#  'music;',
#  'trace.<br',
#  '/>7.8/10',
#  '/>ecstasy',
#  'success.<br',
#  '"worn-out',
#  'bridge--saying',
#  'one!?',
#  'yep,',
#  'music".',
#  'cusack.<br',
#  'comedy.the',
#  'throne,thus',
#  '3/10<br',
#  '"deathtrap".',
#  '(white)',
#  'exclaims',
#  'rózsa',
#  'lust-like-',
#  'be?)',
#  '/>psychotherapist',
#  "maguire',",
#  "porcelain'",
#  'robben',
#  'shakespeare...<br',
#  'captured;',
#  'actor,with',
#  '/>adults',
#  'limey',
#  'lieutenants',
#  'wistfulness:',
#  'eryl',
#  'tough-talking,',
#  'weather"',
#  'hides',
#  '"tong',
#  'neurologist,',
#  'see...it',
#  'perpetuated,',
#  'choppily.',
#  'remastering.',
#  'illusions.<br',
#  'room"\').',
#  'naudet,',
#  'boys"-',
#  'good(i',
#  "carter's",
#  'pioneer',
#  '"lame',
#  'culture".',
#  'connivers',
#  'japes',
#  'rivers,',
#  'them--yet',
#  '"angel"',
#  '(ash',
#  '"thriller',
#  'mawkishly',
#  'risk)',
#  "'mind",
#  '"spm"?',
#  'cross-ethnic',
#  'pot-bellied,',
#  'survive...',
#  'radziwill,',
#  'vegetarian),',
#  'barefooted',
#  'ass-kicker",',
#  'drum/trumpet',
#  'base,',
#  'rosi.',
#  '"10"),',
#  'inherited,',
#  'does(thats',
#  "'afternoon",
#  'shame!)',
#  'nymphs!',
#  'hate.',
#  'worse,bellucci',
#  'farina,',
#  'dell\'orco"',
#  "'grows",
#  "hope's",
#  'you"....',
#  'clarkson),',
#  'dorothy",',
#  'wow...sheer',
#  'wintertime',
#  'success?<br',
#  'bizarre!<br',
#  '/>nsna',
#  'value),',
#  'equipped',
#  'action/comedy/romance',
#  'shape?',
#  '1(laughed)',
#  '^%^%$^$#%@$#@',
#  'swing.',
#  'bails.',
#  '/>aided',
#  '/>joey,',
#  "jet's",
#  'wall\x95e',
#  'beautiful/horrible',
#  'hunks.',
#  'here,if',
#  '"teachers"',
#  'scale?',
#  'faint.however,if',
#  '(wonderful,',
#  '/>trusting',
#  'nose.<br',
#  'vampyre-slayer"',
#  'solution,',
#  'unraveling...<br',
#  '"definitely',
#  "d'ont",
#  'manson-style',
#  'turtle!<br',
#  'non-acting,',
#  '(superbly',
#  '2022:',
#  '"relax!',
#  'animal)...',
#  'voodoo...this',
#  'valentino,',
#  'koyaanisqatsi,',
#  'betweenness.',
#  'hemmerling,',
#  'horns!).',
#  'blankness,',
#  'standoff--slaughter',
#  'colditz',
#  'goodwill,',
#  'illegal',
#  'rewarded',
#  'sect',
#  'knowledge;',
#  'residencia',
#  'murderer',
#  'labeouf),',
#  'fast-tracked',
#  'freddy/jason/micheal',
#  'stalag',
#  'mai-lis',
#  "bodyguard's",
#  'gazpacho',
#  'inspiring---plus,',
#  'making<br',
#  'royaume',
#  'strangulation',
#  'prevalent.',
#  'knights',
#  "there'.",
#  'temecula',
#  'enrichment',
#  'duets,',
#  'auteuil.',
#  'corrupter',
#  'face!!',
#  'centenary,',
#  'teenager!',
#  'heartthrob',
#  'ready!"<br',
#  'catdog',
#  'aiw,',
#  '(tmc)',
#  'state.helping',
#  'least:',
#  'surfacing',
#  'leagues...',
#  'valse',
#  'idol,"',
#  'watching...watching',
#  'maltin"',
#  'kansas.<br',
#  'jeannot',
#  '"missing".',
#  'mobiles',
#  "izzy's",
#  'trained!!!',
#  'sign-on',
#  "duh...don't",
#  'sleekly,',
#  'twiggy',
#  'becomes...glenda!',
#  'hymns',
#  'men.gunga',
#  'stablemate',
#  'television.<br',
#  'creepiest,',
#  'paris;',
#  'cooed.',
#  'failures/3-5-0-0,"',
#  'bartin',
#  'stagnantly',
#  'musicianship',
#  'kokkinos',
#  'amin,',
#  'constellations',
#  'imaginable.<br',
#  'contributors,with',
#  'award-worthy,',
#  'arielle',
#  'helped?',
#  '10-to-1',
#  'retrieval,',
#  'thorough',
#  'glassey',
#  'haggisreally',
#  'matters******<br',
#  "(80's",
#  'daneliuc.<br',
#  'mainframe',
#  "mcnamara's",
#  '(re-titled',
#  'occaisionally',
#  'spencer)',
#  'day);',
#  '"expendable"',
#  'splendor"',
#  'rachel)',
#  '/>guiness',
#  'hairspray',
#  'aire,',
#  'radiantly',
#  '"pittsburgh")',
#  'vince',
#  '(circa',
#  'cherry',
#  'animalplanet',
#  'punchline.<br',
#  'gelato',
#  'thorson',
#  'byner',
#  'wither',
#  '"lackawanna',
#  'hanfstaengl`s',
#  '104?)',
#  'endearing...',
#  'swat-team',
#  'unresolved,',
#  'kar-wai;',
#  "'now'",
#  'ice-cold,',
#  'sheltered,',
#  '/>blowback:',
#  'dumb..',
#  'punsley',
#  "toys'",
#  '£8,000',
#  'theirs)',
#  "ardolino's",
#  'groovay,',
#  'mt.',
#  'secret/weakness',
#  '("deep',
#  'bullosa',
#  'goines',
#  'product.the',
#  'lovely;',
#  'honoured',
#  'publicist,',
#  '"evil",',
#  'weired',
#  'carelessness.',
#  'songs!!!',
#  '"there',
#  'pre-screening',
#  'memories")',
#  "bard's",
#  'artifacts.',
#  'self-determination',
#  'propaganda?',
#  "mostel's",
#  'co-owner',
#  'unmet',
#  'pianiste',
#  'interiors,',
#  'kuhn,',
#  'enrages',
#  'cushing;',
#  '"napalm',
#  'around?),',
#  'cast".',
#  'obesity,',
#  'unexplained)during',
#  'shockingly,',
#  "'tron'",
#  'calvary,',
#  'maybe',
#  'closest.<br',
#  'alan,',
#  'segments.<br',
#  'scariest.',
#  'lush',
#  'telly',
#  'it"--or',
#  'musical")',
#  'headaches!<br',
#  'war-struck',
#  '(reeves),',
#  'meaningless-',
#  'non-egyptian,',
#  "two'.",
#  'like!<br',
#  '"watchable"',
#  'dodge-ball,',
#  'beseige',
#  "ghai's",
#  'omnipresent.',
#  '(barnyard)',
#  'mad-doctor',
#  'gunslinger.',
#  'cults?',
#  'jennifer',
#  'hirsch,',
#  'champaign!',
#  '"play"',
#  'nitpickers,',
#  'rockythebear',
#  'downhill."',
#  'quick-paced',
#  'repression-leading-to-predation',
#  'co-ceo',
#  "famous,borzage's",
#  'alert:',
#  'youth.',
#  'mundane;',
#  'intelligently,',
#  'worrell',
#  'crucifix.',
#  '(francine',
#  'klansmen,going',
#  '"elements"',
#  "'flambards',",
#  'weiss,',
#  'action-music',
#  'glassed',
#  'etc...)and',
#  'insurgence',
#  'unbelievable!!',
#  '("spinal',
#  'neal(jason',
#  'baxter",',
#  'bhang',
#  'state...',
#  '"pedofile"',
#  'pah',
#  'spiderbait',
#  'accordian',
#  'whore.',
#  'one-linear',
#  'real?"',
#  'mouths."<br',
#  '350,000',
#  '"plot',
#  'waldermar',
#  'two:',
#  'sinhue',
#  'motivations:',
#  '(marine',
#  'dobkins',
#  'alternates.',
#  'ransom.....',
#  'cardigan,',
#  'family.homeward',
#  'scorch,',
#  '/>supermen',
#  'ballpoint',
#  'wack,',
#  'transmit',
#  'twist...and',
#  'sports-related',
#  'completes',
#  'finishes.<br',
#  "isn't.),",
#  'ones.the',
#  'levels:',
#  'port',
#  'exacerbate',
#  '"author"',
#  '"rape',
#  'sing!"',
#  'diehl),',
#  'one.i',
#  'marine."',
#  'horrorvision',
#  'hallucinations',
#  'pent-up',
#  'involved.but',
#  'predetermining',
#  'apophis,',
#  "''ranma",
#  "'beau'/son",
#  'nora)',
#  'mocha',
#  'corcorin',
#  '"actress."',
#  'overly-explanatory',
#  'marylee',
#  'watson.basil',
#  'xxth',
#  'lita',
#  'southeast,',
#  'mna',
#  '*be',
#  '"l\'appartement"',
#  'semi-doc',
#  'someone;',
#  'cregar).',
#  'valiant"',
#  'hoodlums,',
#  'acting...etc,',
#  'connective',
#  'introspection,',
#  "made.it's",
#  'shivers.',
#  'retrogressive',
#  'functionaries',
#  '(tv-asia).',
#  'all--at',
#  'hour+',
#  'mccaid,',
#  'nomination',
#  'laughton',
#  '("anti-pesto"',
#  'cylon',
#  'aquarius!',
#  'for.throw',
#  "genre'",
#  'convulsion.',
#  'artificially.',
#  'case."',
#  'general(1949))',
#  'again)-',
#  'unmusical,',
#  'peers"',
#  'delia,',
#  'roles........<br',
#  'underwoods',
#  "bomber's",
#  'abides',
#  'partnered',
#  'brainless,',
#  'north/south',
#  "elise'",
#  'defector',
#  'cry".',
#  'feminism?',
#  '(marcy)',
#  'teleports',
#  'junkies?',
#  'crooks,with',
#  'b-film-love-drama.',
#  "''swingin'",
#  '3/6',
#  "'following'.",
#  'miljan).',
#  'known,',
#  "also'",
#  'k-11',
#  'sequel,',
#  'antiquated,',
#  'overlooked.',
#  'vociferously.',
#  'too.<br',
#  'cover/poster',
#  'bhosle',
#  'incredibles".',
#  'stop?<br',
#  '(larraz',
#  'rasta.',
#  '/>heinlein',
#  '"presence".',
#  'sergeant)',
#  'sukowa),',
#  'nitti',
#  'arm?',
#  'chucky,',
#  'remember"',
#  'contempo',
#  'reschedule,',
#  '/>lucky',
#  'slump?',
#  'not-so-disinterested',
#  '(fassbinder',
#  'small.',
#  'darlene,',
#  'words.',
#  '/>arlon',
#  "buell's",
#  'yip).',
#  'wednesday,',
#  'term).',
#  'non-admirer',
#  'gabe,',
#  'homesteaders.',
#  "mccrea's,",
#  'thumbs-up',
#  '£50',
#  'rapes',
#  'win),',
#  'deaf,',
#  "scorpion'.",
#  'too)goes',
#  'countryfolk.',
#  "durante's",
#  '(nastassja',
#  'fashion...',
#  "radu's",
#  'wonderfully.',
#  "toto',",
#  'grit,"',
#  'titan',
#  'ghetto,',
#  'script.',
#  'set.i',
#  'hinson)',
#  "suicune's",
#  'disadvantage',
#  '"engagement',
#  'people-orson',
#  ...}

# %%
word_to_idx
# Out:
# {'strawberry': 1,
#  'bob!<br': 2,
#  'audience_great': 3,
#  'bullying.': 4,
#  'g-man': 5,
#  'scourge,': 6,
#  'anansie': 7,
#  '/>poo': 8,
#  'jäniksen': 9,
#  '(repetitious': 10,
#  'borders!),': 11,
#  'alien-costume': 12,
#  'tawny': 13,
#  'too...whoa!': 14,
#  'multimillionaire': 15,
#  'shielded': 16,
#  'noblesse': 17,
#  'simon?)': 18,
#  'coast-meets-': 19,
#  'process,"': 20,
#  'governator': 21,
#  'jokes,"': 22,
#  'whatsoever...i': 23,
#  'rendering,': 24,
#  'offers.': 25,
#  'zoos': 26,
#  'nerf': 27,
#  'main-writer': 28,
#  "o'daniel.": 29,
#  'pouting': 30,
#  'al-mutairi"': 31,
#  '(shirdi': 32,
#  'loooooove': 33,
#  '"extras."': 34,
#  'complicit': 35,
#  'loomis.<br': 36,
#  '21.)<br': 37,
#  'europe:': 38,
#  'impassive': 39,
#  '(useless)': 40,
#  '"specialagentfoxmulder"': 41,
#  'warnercolor': 42,
#  '"little': 43,
#  'stage).': 44,
#  'wisecracks!)': 45,
#  'others").': 46,
#  'snooze-fests': 47,
#  'objective;': 48,
#  'hamburger.': 49,
#  'preparations.': 50,
#  'bookish.<br': 51,
#  '"incidents"': 52,
#  'co-ordinate': 53,
#  '(1992).': 54,
#  '/>wrong!': 55,
#  'ziplock': 56,
#  'killers!': 57,
#  'story".<br': 58,
#  'fabulous-': 59,
#  'firmer".': 60,
#  'firearms;': 61,
#  'screamy': 62,
#  'romeo&juliet': 63,
#  'deesh".': 64,
#  '200mph': 65,
#  'pairs,': 66,
#  'vidler': 67,
#  "bert's": 68,
#  'beaton)': 69,
#  'stupified': 70,
#  'gentle"': 71,
#  "'must": 72,
#  'interviewer:': 73,
#  'depressing.but': 74,
#  '"chemistry."': 75,
#  'slasher/comic': 76,
#  'bandit",': 77,
#  'background")': 78,
#  'employee?': 79,
#  'matrix."<br': 80,
#  'aunt?': 81,
#  'indiscernible,': 82,
#  "'over-act',": 83,
#  'villains:5': 84,
#  '1959-1973.': 85,
#  'ape-hater': 86,
#  'apanowicz': 87,
#  'andrésen)': 88,
#  'corman...': 89,
#  'compulsion.': 90,
#  '"vellai': 91,
#  'akshaye-ayesha': 92,
#  'decimals': 93,
#  '"cardassian"': 94,
#  '"parisian"': 95,
#  'piglets': 96,
#  'hopping': 97,
#  'endings;': 98,
#  'rainman': 99,
#  'wide-screen,': 100,
#  "mobster's": 101,
#  'buzzard,': 102,
#  'spider-web': 103,
#  'superman.': 104,
#  'kombat.': 105,
#  'angst-driven': 106,
#  "fairbanks's": 107,
#  'alliteration.': 108,
#  'suckfest.': 109,
#  'umm..': 110,
#  'tragedy)': 111,
#  'better(as': 112,
#  'paper,nick': 113,
#  'bottom-to-mid': 114,
#  "ellington's": 115,
#  "want's": 116,
#  'over-heard': 117,
#  'either...they': 118,
#  'wryness': 119,
#  'dullllllllllll.': 120,
#  'antecedent': 121,
#  '"massa\'s': 122,
#  'closeups)': 123,
#  '36??': 124,
#  'suggest--': 125,
#  'liberal,': 126,
#  'best..': 127,
#  '(thats': 128,
#  'window????': 129,
#  'certification': 130,
#  "caitlin's": 131,
#  'askeys': 132,
#  'testify': 133,
#  'afterwards!!': 134,
#  'chickens?"': 135,
#  '/>grisby': 136,
#  'cassanova': 137,
#  'dweezil': 138,
#  'absent.)': 139,
#  'msrk': 140,
#  'downstream,': 141,
#  'kohli,': 142,
#  'pocket': 143,
#  'build-up': 144,
#  'emily(joan': 145,
#  '(hanzo': 146,
#  "segment'": 147,
#  '(duncan)': 148,
#  'yum-yum.<br': 149,
#  'soggy,': 150,
#  'novel)': 151,
#  'purposes--more': 152,
#  'arte),': 153,
#  'scab': 154,
#  'admission.': 155,
#  'likes:': 156,
#  'points»': 157,
#  'storeroom,': 158,
#  'know?<br': 159,
#  'pops".': 160,
#  'inner-emotions': 161,
#  'them--despite': 162,
#  'tonik,': 163,
#  '(waterbury,': 164,
#  'naturally.': 165,
#  '/>implausible': 166,
#  'pre-ilm': 167,
#  'trashman': 168,
#  'wb-quality': 169,
#  'doggies,': 170,
#  'shining"---but': 171,
#  'version-': 172,
#  'smells,': 173,
#  'reviewing': 174,
#  'watson.': 175,
#  'mcgregors': 176,
#  'ab': 177,
#  'hard-to-swallow': 178,
#  '\'extraordinary."': 179,
#  'licence': 180,
#  'sheep': 181,
#  'brake-dancing': 182,
#  'chintzy.<br': 183,
#  'somnolent': 184,
#  '(tokoro': 185,
#  'nr.6': 186,
#  'cammareri': 187,
#  'austrailan': 188,
#  'interviewed..."': 189,
#  'confrontations/fight': 190,
#  '"hey...remember': 191,
#  'rubric.<br': 192,
#  '"nightbeast",': 193,
#  'sexpot"': 194,
#  '"died': 195,
#  'binging': 196,
#  'overstepping': 197,
#  'movies...or': 198,
#  'muckraking': 199,
#  'midway.': 200,
#  'heroin?': 201,
#  'blain': 202,
#  'nine-year-old,': 203,
#  "shoot'n'run": 204,
#  "snicket's": 205,
#  '/>"boogie': 206,
#  'character--so': 207,
#  'bichunmoo': 208,
#  'cubitt}': 209,
#  "belgium's": 210,
#  'roughest,': 211,
#  'schleps': 212,
#  "'everyone'": 213,
#  'brimley,': 214,
#  'restaraunt': 215,
#  'woolf?"': 216,
#  '("ooh': 217,
#  '(absent)': 218,
#  "jumbaa's": 219,
#  "deceased--it's": 220,
#  "away...don't": 221,
#  'lines:': 222,
#  'salted': 223,
#  '8.50': 224,
#  "'nanites'?": 225,
#  'reminisce': 226,
#  'ta,': 227,
#  'maintains.': 228,
#  'guðnason),': 229,
#  'people-"psst,': 230,
#  "verel's": 231,
#  'sumo...': 232,
#  'al-yusuf': 233,
#  'mussolini': 234,
#  'ex-con.': 235,
#  'bwahahahahha.': 236,
#  '"marshovia",': 237,
#  'eludes': 238,
#  "intentions',": 239,
#  'sub-category': 240,
#  'dakotas,': 241,
#  'litel),': 242,
#  'conceive': 243,
#  'neat-freak': 244,
#  '37),': 245,
#  'underling': 246,
#  'dealers.<br': 247,
#  'patrons;funk': 248,
#  'candy...which': 249,
#  'altering.': 250,
#  "/>cain's": 251,
#  'falsification': 252,
#  'fairly,': 253,
#  '/>fade': 254,
#  'however!),': 255,
#  'tonks.': 256,
#  'finnell': 257,
#  'harlech': 258,
#  'life!<br': 259,
#  'tall").': 260,
#  'metaphorical).': 261,
#  "cardiff's": 262,
#  'unenviable': 263,
#  'day,"': 264,
#  'hilarious.they': 265,
#  'hemmitt': 266,
#  'mogadon?': 267,
#  'mob.': 268,
#  'enjoy...bade': 269,
#  'chip"': 270,
#  'freshly-undead': 271,
#  'cat!"': 272,
#  'the...???english': 273,
#  "continent'": 274,
#  'turbocharger': 275,
#  'abuse...did': 276,
#  'eloquence.': 277,
#  'attests.': 278,
#  'circumstance': 279,
#  'fresca"': 280,
#  'celluloid-particularly': 281,
#  'schroeder:': 282,
#  'erections,': 283,
#  '\x84comedy"': 284,
#  'her?': 285,
#  'planned:': 286,
#  '/>benicio': 287,
#  '/>shawn': 288,
#  '$400.00.': 289,
#  'dentist",': 290,
#  '7/7': 291,
#  'periods;': 292,
#  'backwards...<br': 293,
#  "character--he's": 294,
#  'killjoy.<br': 295,
#  'gore/death': 296,
#  'pluses-': 297,
#  'becky(jena': 298,
#  '/>hero:': 299,
#  '10-odd': 300,
#  "dk's": 301,
#  ',please!").<br': 302,
#  'swimsuits': 303,
#  'facility).': 304,
#  'hughes),': 305,
#  'comedy...but': 306,
#  'honeymooners,"': 307,
#  '(zlatorog': 308,
#  'caricature?': 309,
#  '"c+"': 310,
#  'filming': 311,
#  'breillat.': 312,
#  'matter,': 313,
#  "candidate'": 314,
#  '*revenge': 315,
#  'lotto': 316,
#  'mishmashes,': 317,
#  'park...errr...the': 318,
#  'immemorial).<br': 319,
#  'weakness--women.': 320,
#  'shackled': 321,
#  "kathleen's": 322,
#  'gordon"': 323,
#  'sense?': 324,
#  'act...if': 325,
#  'mustaches.': 326,
#  'area;': 327,
#  "danver's": 328,
#  'coughlan.': 329,
#  'un-appealing': 330,
#  'legs': 331,
#  'crocks': 332,
#  '"s"': 333,
#  '"cheers")': 334,
#  'woodhouse..i': 335,
#  'flapping.': 336,
#  'roles.but': 337,
#  'subsequently': 338,
#  'irrelevancies,': 339,
#  '(bates': 340,
#  '"surrealist"': 341,
#  'mateo,': 342,
#  'guy/sci-fi': 343,
#  '7",': 344,
#  "'social'": 345,
#  'over-the-top.': 346,
#  'daniels).<br': 347,
#  'scene-stealer': 348,
#  '"gilda"': 349,
#  'www.reel13.org)': 350,
#  'coconut': 351,
#  'multi-racial,': 352,
#  'brutality-on-video,': 353,
#  'daniela': 354,
#  'continent"': 355,
#  'opposite!': 356,
#  'gorgous': 357,
#  'colagrande': 358,
#  'funnier!': 359,
#  'strada.': 360,
#  'davies,': 361,
#  'saveles:': 362,
#  'illness?': 363,
#  'rampage,"': 364,
#  'it.all': 365,
#  'self-importance.<br': 366,
#  'resurrection",': 367,
#  'revolutionary,': 368,
#  'scarf/pashmina/shawl': 369,
#  'neo-film': 370,
#  'sleazo': 371,
#  '"outbreak"},': 372,
#  'scratched-up': 373,
#  't"--seriously,': 374,
#  'wanted-': 375,
#  'racist)': 376,
#  'grave.<br': 377,
#  'simms,': 378,
#  'dumb).': 379,
#  'zandalee': 380,
#  'apostoles?': 381,
#  "rostov's": 382,
#  'search.': 383,
#  'homosexual.<br': 384,
#  '(granted': 385,
#  'brandon,': 386,
#  'well-to-do': 387,
#  'this....the': 388,
#  '"highlands': 389,
#  'khanna.its': 390,
#  'cylinder!"': 391,
#  '2gether!': 392,
#  '1/2/': 393,
#  'okuhara': 394,
#  'society",': 395,
#  'railed': 396,
#  '"bay': 397,
#  'embezzled': 398,
#  'always-lovely': 399,
#  '[xizhao]': 400,
#  'cast/extras': 401,
#  'approximately': 402,
#  'contextual': 403,
#  "movie''don't": 404,
#  'scar.': 405,
#  'sereia': 406,
#  'comic-relief': 407,
#  'sick--like': 408,
#  'jowly)': 409,
#  'assignment.': 410,
#  'horrifying.': 411,
#  'merkurjev,': 412,
#  'pro-americanism': 413,
#  "'clever": 414,
#  'bomfunk': 415,
#  '(wether': 416,
#  'feathers:': 417,
#  'aesthetical': 418,
#  'happens.jokes': 419,
#  '/>michelle': 420,
#  "'seance'": 421,
#  'feedback.': 422,
#  "powell/pressburger's": 423,
#  'grave!)': 424,
#  'rip-offs;': 425,
#  'murders),': 426,
#  'partners?': 427,
#  'decided-upon': 428,
#  '(ctrl+c,': 429,
#  'fun/good': 430,
#  'hardcores.': 431,
#  'english-speaking': 432,
#  'brite': 433,
#  'backfires,': 434,
#  'confined.<br': 435,
#  'blue-green': 436,
#  'lilt': 437,
#  'hammer).': 438,
#  'begotten"': 439,
#  'yesteryear': 440,
#  '^-^<br': 441,
#  'calls)': 442,
#  'pocatello,': 443,
#  'piston': 444,
#  'tian.': 445,
#  'nasal': 446,
#  '"zatoichi"': 447,
#  'penguins)': 448,
#  'rotation,': 449,
#  'highlands': 450,
#  'brown(homecoming': 451,
#  '1938);': 452,
#  'undercurrent': 453,
#  'elsie': 454,
#  'graham),': 455,
#  '("rocky': 456,
#  '/>(ok,': 457,
#  'unknowns.': 458,
#  'pretendeous': 459,
#  'bertin).': 460,
#  'pacula).': 461,
#  "pupil')": 462,
#  'quivering.': 463,
#  'since--and': 464,
#  '(luckly': 465,
#  'f@#$': 466,
#  'junked': 467,
#  'race).': 468,
#  "'gremlins'.": 469,
#  '1974).': 470,
#  'exchange': 471,
#  '"asylum': 472,
#  'better--than': 473,
#  'waffle..': 474,
#  'girlfriend),': 475,
#  'manhunt': 476,
#  "`love'": 477,
#  'music;': 478,
#  'trace.<br': 479,
#  '/>7.8/10': 480,
#  '/>ecstasy': 481,
#  'success.<br': 482,
#  '"worn-out': 483,
#  'bridge--saying': 484,
#  'one!?': 485,
#  'yep,': 486,
#  'music".': 487,
#  'cusack.<br': 488,
#  'comedy.the': 489,
#  'throne,thus': 490,
#  '3/10<br': 491,
#  '"deathtrap".': 492,
#  '(white)': 493,
#  'exclaims': 494,
#  'rózsa': 495,
#  'lust-like-': 496,
#  'be?)': 497,
#  '/>psychotherapist': 498,
#  "maguire',": 499,
#  "porcelain'": 500,
#  'robben': 501,
#  'shakespeare...<br': 502,
#  'captured;': 503,
#  'actor,with': 504,
#  '/>adults': 505,
#  'limey': 506,
#  'lieutenants': 507,
#  'wistfulness:': 508,
#  'eryl': 509,
#  'tough-talking,': 510,
#  'weather"': 511,
#  'hides': 512,
#  '"tong': 513,
#  'neurologist,': 514,
#  'see...it': 515,
#  'perpetuated,': 516,
#  'choppily.': 517,
#  'remastering.': 518,
#  'illusions.<br': 519,
#  'room"\').': 520,
#  'naudet,': 521,
#  'boys"-': 522,
#  'good(i': 523,
#  "carter's": 524,
#  'pioneer': 525,
#  '"lame': 526,
#  'culture".': 527,
#  'connivers': 528,
#  'japes': 529,
#  'rivers,': 530,
#  'them--yet': 531,
#  '"angel"': 532,
#  '(ash': 533,
#  '"thriller': 534,
#  'mawkishly': 535,
#  'risk)': 536,
#  "'mind": 537,
#  '"spm"?': 538,
#  'cross-ethnic': 539,
#  'pot-bellied,': 540,
#  'survive...': 541,
#  'radziwill,': 542,
#  'vegetarian),': 543,
#  'barefooted': 544,
#  'ass-kicker",': 545,
#  'drum/trumpet': 546,
#  'base,': 547,
#  'rosi.': 548,
#  '"10"),': 549,
#  'inherited,': 550,
#  'does(thats': 551,
#  "'afternoon": 552,
#  'shame!)': 553,
#  'nymphs!': 554,
#  'hate.': 555,
#  'worse,bellucci': 556,
#  'farina,': 557,
#  'dell\'orco"': 558,
#  "'grows": 559,
#  "hope's": 560,
#  'you"....': 561,
#  'clarkson),': 562,
#  'dorothy",': 563,
#  'wow...sheer': 564,
#  'wintertime': 565,
#  'success?<br': 566,
#  'bizarre!<br': 567,
#  '/>nsna': 568,
#  'value),': 569,
#  'equipped': 570,
#  'action/comedy/romance': 571,
#  'shape?': 572,
#  '1(laughed)': 573,
#  '^%^%$^$#%@$#@': 574,
#  'swing.': 575,
#  'bails.': 576,
#  '/>aided': 577,
#  '/>joey,': 578,
#  "jet's": 579,
#  'wall\x95e': 580,
#  'beautiful/horrible': 581,
#  'hunks.': 582,
#  'here,if': 583,
#  '"teachers"': 584,
#  'scale?': 585,
#  'faint.however,if': 586,
#  '(wonderful,': 587,
#  '/>trusting': 588,
#  'nose.<br': 589,
#  'vampyre-slayer"': 590,
#  'solution,': 591,
#  'unraveling...<br': 592,
#  '"definitely': 593,
#  "d'ont": 594,
#  'manson-style': 595,
#  'turtle!<br': 596,
#  'non-acting,': 597,
#  '(superbly': 598,
#  '2022:': 599,
#  '"relax!': 600,
#  'animal)...': 601,
#  'voodoo...this': 602,
#  'valentino,': 603,
#  'koyaanisqatsi,': 604,
#  'betweenness.': 605,
#  'hemmerling,': 606,
#  'horns!).': 607,
#  'blankness,': 608,
#  'standoff--slaughter': 609,
#  'colditz': 610,
#  'goodwill,': 611,
#  'illegal': 612,
#  'rewarded': 613,
#  'sect': 614,
#  'knowledge;': 615,
#  'residencia': 616,
#  'murderer': 617,
#  'labeouf),': 618,
#  'fast-tracked': 619,
#  'freddy/jason/micheal': 620,
#  'stalag': 621,
#  'mai-lis': 622,
#  "bodyguard's": 623,
#  'gazpacho': 624,
#  'inspiring---plus,': 625,
#  'making<br': 626,
#  'royaume': 627,
#  'strangulation': 628,
#  'prevalent.': 629,
#  'knights': 630,
#  "there'.": 631,
#  'temecula': 632,
#  'enrichment': 633,
#  'duets,': 634,
#  'auteuil.': 635,
#  'corrupter': 636,
#  'face!!': 637,
#  'centenary,': 638,
#  'teenager!': 639,
#  'heartthrob': 640,
#  'ready!"<br': 641,
#  'catdog': 642,
#  'aiw,': 643,
#  '(tmc)': 644,
#  'state.helping': 645,
#  'least:': 646,
#  'surfacing': 647,
#  'leagues...': 648,
#  'valse': 649,
#  'idol,"': 650,
#  'watching...watching': 651,
#  'maltin"': 652,
#  'kansas.<br': 653,
#  'jeannot': 654,
#  '"missing".': 655,
#  'mobiles': 656,
#  "izzy's": 657,
#  'trained!!!': 658,
#  'sign-on': 659,
#  "duh...don't": 660,
#  'sleekly,': 661,
#  'twiggy': 662,
#  'becomes...glenda!': 663,
#  'hymns': 664,
#  'men.gunga': 665,
#  'stablemate': 666,
#  'television.<br': 667,
#  'creepiest,': 668,
#  'paris;': 669,
#  'cooed.': 670,
#  'failures/3-5-0-0,"': 671,
#  'bartin': 672,
#  'stagnantly': 673,
#  'musicianship': 674,
#  'kokkinos': 675,
#  'amin,': 676,
#  'constellations': 677,
#  'imaginable.<br': 678,
#  'contributors,with': 679,
#  'award-worthy,': 680,
#  'arielle': 681,
#  'helped?': 682,
#  '10-to-1': 683,
#  'retrieval,': 684,
#  'thorough': 685,
#  'glassey': 686,
#  'haggisreally': 687,
#  'matters******<br': 688,
#  "(80's": 689,
#  'daneliuc.<br': 690,
#  'mainframe': 691,
#  "mcnamara's": 692,
#  '(re-titled': 693,
#  'occaisionally': 694,
#  'spencer)': 695,
#  'day);': 696,
#  '"expendable"': 697,
#  'splendor"': 698,
#  'rachel)': 699,
#  '/>guiness': 700,
#  'hairspray': 701,
#  'aire,': 702,
#  'radiantly': 703,
#  '"pittsburgh")': 704,
#  'vince': 705,
#  '(circa': 706,
#  'cherry': 707,
#  'animalplanet': 708,
#  'punchline.<br': 709,
#  'gelato': 710,
#  'thorson': 711,
#  'byner': 712,
#  'wither': 713,
#  '"lackawanna': 714,
#  'hanfstaengl`s': 715,
#  '104?)': 716,
#  'endearing...': 717,
#  'swat-team': 718,
#  'unresolved,': 719,
#  'kar-wai;': 720,
#  "'now'": 721,
#  'ice-cold,': 722,
#  'sheltered,': 723,
#  '/>blowback:': 724,
#  'dumb..': 725,
#  'punsley': 726,
#  "toys'": 727,
#  '£8,000': 728,
#  'theirs)': 729,
#  "ardolino's": 730,
#  'groovay,': 731,
#  'mt.': 732,
#  'secret/weakness': 733,
#  '("deep': 734,
#  'bullosa': 735,
#  'goines': 736,
#  'product.the': 737,
#  'lovely;': 738,
#  'honoured': 739,
#  'publicist,': 740,
#  '"evil",': 741,
#  'weired': 742,
#  'carelessness.': 743,
#  'songs!!!': 744,
#  '"there': 745,
#  'pre-screening': 746,
#  'memories")': 747,
#  "bard's": 748,
#  'artifacts.': 749,
#  'self-determination': 750,
#  'propaganda?': 751,
#  "mostel's": 752,
#  'co-owner': 753,
#  'unmet': 754,
#  'pianiste': 755,
#  'interiors,': 756,
#  'kuhn,': 757,
#  'enrages': 758,
#  'cushing;': 759,
#  '"napalm': 760,
#  'around?),': 761,
#  'cast".': 762,
#  'obesity,': 763,
#  'unexplained)during': 764,
#  'shockingly,': 765,
#  "'tron'": 766,
#  'calvary,': 767,
#  'maybe': 768,
#  'closest.<br': 769,
#  'alan,': 770,
#  'segments.<br': 771,
#  'scariest.': 772,
#  'lush': 773,
#  'telly': 774,
#  'it"--or': 775,
#  'musical")': 776,
#  'headaches!<br': 777,
#  'war-struck': 778,
#  '(reeves),': 779,
#  'meaningless-': 780,
#  'non-egyptian,': 781,
#  "two'.": 782,
#  'like!<br': 783,
#  '"watchable"': 784,
#  'dodge-ball,': 785,
#  'beseige': 786,
#  "ghai's": 787,
#  'omnipresent.': 788,
#  '(barnyard)': 789,
#  'mad-doctor': 790,
#  'gunslinger.': 791,
#  'cults?': 792,
#  'jennifer': 793,
#  'hirsch,': 794,
#  'champaign!': 795,
#  '"play"': 796,
#  'nitpickers,': 797,
#  'rockythebear': 798,
#  'downhill."': 799,
#  'quick-paced': 800,
#  'repression-leading-to-predation': 801,
#  'co-ceo': 802,
#  "famous,borzage's": 803,
#  'alert:': 804,
#  'youth.': 805,
#  'mundane;': 806,
#  'intelligently,': 807,
#  'worrell': 808,
#  'crucifix.': 809,
#  '(francine': 810,
#  'klansmen,going': 811,
#  '"elements"': 812,
#  "'flambards',": 813,
#  'weiss,': 814,
#  'action-music': 815,
#  'glassed': 816,
#  'etc...)and': 817,
#  'insurgence': 818,
#  'unbelievable!!': 819,
#  '("spinal': 820,
#  'neal(jason': 821,
#  'baxter",': 822,
#  'bhang': 823,
#  'state...': 824,
#  '"pedofile"': 825,
#  'pah': 826,
#  'spiderbait': 827,
#  'accordian': 828,
#  'whore.': 829,
#  'one-linear': 830,
#  'real?"': 831,
#  'mouths."<br': 832,
#  '350,000': 833,
#  '"plot': 834,
#  'waldermar': 835,
#  'two:': 836,
#  'sinhue': 837,
#  'motivations:': 838,
#  '(marine': 839,
#  'dobkins': 840,
#  'alternates.': 841,
#  'ransom.....': 842,
#  'cardigan,': 843,
#  'family.homeward': 844,
#  'scorch,': 845,
#  '/>supermen': 846,
#  'ballpoint': 847,
#  'wack,': 848,
#  'transmit': 849,
#  'twist...and': 850,
#  'sports-related': 851,
#  'completes': 852,
#  'finishes.<br': 853,
#  "isn't.),": 854,
#  'ones.the': 855,
#  'levels:': 856,
#  'port': 857,
#  'exacerbate': 858,
#  '"author"': 859,
#  '"rape': 860,
#  'sing!"': 861,
#  'diehl),': 862,
#  'one.i': 863,
#  'marine."': 864,
#  'horrorvision': 865,
#  'hallucinations': 866,
#  'pent-up': 867,
#  'involved.but': 868,
#  'predetermining': 869,
#  'apophis,': 870,
#  "''ranma": 871,
#  "'beau'/son": 872,
#  'nora)': 873,
#  'mocha': 874,
#  'corcorin': 875,
#  '"actress."': 876,
#  'overly-explanatory': 877,
#  'marylee': 878,
#  'watson.basil': 879,
#  'xxth': 880,
#  'lita': 881,
#  'southeast,': 882,
#  'mna': 883,
#  '*be': 884,
#  '"l\'appartement"': 885,
#  'semi-doc': 886,
#  'someone;': 887,
#  'cregar).': 888,
#  'valiant"': 889,
#  'hoodlums,': 890,
#  'acting...etc,': 891,
#  'connective': 892,
#  'introspection,': 893,
#  "made.it's": 894,
#  'shivers.': 895,
#  'retrogressive': 896,
#  'functionaries': 897,
#  '(tv-asia).': 898,
#  'all--at': 899,
#  'hour+': 900,
#  'mccaid,': 901,
#  'nomination': 902,
#  'laughton': 903,
#  '("anti-pesto"': 904,
#  'cylon': 905,
#  'aquarius!': 906,
#  'for.throw': 907,
#  "genre'": 908,
#  'convulsion.': 909,
#  'artificially.': 910,
#  'case."': 911,
#  'general(1949))': 912,
#  'again)-': 913,
#  'unmusical,': 914,
#  'peers"': 915,
#  'delia,': 916,
#  'roles........<br': 917,
#  'underwoods': 918,
#  "bomber's": 919,
#  'abides': 920,
#  'partnered': 921,
#  'brainless,': 922,
#  'north/south': 923,
#  "elise'": 924,
#  'defector': 925,
#  'cry".': 926,
#  'feminism?': 927,
#  '(marcy)': 928,
#  'teleports': 929,
#  'junkies?': 930,
#  'crooks,with': 931,
#  'b-film-love-drama.': 932,
#  "''swingin'": 933,
#  '3/6': 934,
#  "'following'.": 935,
#  'miljan).': 936,
#  'known,': 937,
#  "also'": 938,
#  'k-11': 939,
#  'sequel,': 940,
#  'antiquated,': 941,
#  'overlooked.': 942,
#  'vociferously.': 943,
#  'too.<br': 944,
#  'cover/poster': 945,
#  'bhosle': 946,
#  'incredibles".': 947,
#  'stop?<br': 948,
#  '(larraz': 949,
#  'rasta.': 950,
#  '/>heinlein': 951,
#  '"presence".': 952,
#  'sergeant)': 953,
#  'sukowa),': 954,
#  'nitti': 955,
#  'arm?': 956,
#  'chucky,': 957,
#  'remember"': 958,
#  'contempo': 959,
#  'reschedule,': 960,
#  '/>lucky': 961,
#  'slump?': 962,
#  'not-so-disinterested': 963,
#  '(fassbinder': 964,
#  'small.': 965,
#  'darlene,': 966,
#  'words.': 967,
#  '/>arlon': 968,
#  "buell's": 969,
#  'yip).': 970,
#  'wednesday,': 971,
#  'term).': 972,
#  'non-admirer': 973,
#  'gabe,': 974,
#  'homesteaders.': 975,
#  "mccrea's,": 976,
#  'thumbs-up': 977,
#  '£50': 978,
#  'rapes': 979,
#  'win),': 980,
#  'deaf,': 981,
#  "scorpion'.": 982,
#  'too)goes': 983,
#  'countryfolk.': 984,
#  "durante's": 985,
#  '(nastassja': 986,
#  'fashion...': 987,
#  "radu's": 988,
#  'wonderfully.': 989,
#  "toto',": 990,
#  'grit,"': 991,
#  'titan': 992,
#  'ghetto,': 993,
#  'script.': 994,
#  'set.i': 995,
#  'hinson)': 996,
#  "suicune's": 997,
#  'disadvantage': 998,
#  '"engagement': 999,
#  'people-orson': 1000,
#  ...}

# %%
def encode_and_pad(text):
    encoded = [word_to_idx[word] for word in text]
    return encoded + [0] * (max_length - len(encoded))

train_data['review'] = train_data['review'].apply(encode_and_pad)
test_data['review'] = test_data['review'].apply(encode_and_pad)

# %%
test_data.head()
# Out:
#                                                   review  sentiment
# 33553  [301370, 226075, 353859, 284744, 191603, 38463...          1
# 9427   [238149, 365115, 334713, 269262, 299038, 31997...          1
# 199    [143420, 357903, 224646, 329953, 319977, 16898...          0
# 12447  [340320, 285135, 323088, 179240, 156834, 14806...          1
# 39489  [208179, 218278, 222653, 267135, 248931, 39553...          0

# %%
class SentimentDataset(Dataset):
    def __init__(self, data):
        self.texts = data['review'].values
        self.labels = data['sentiment'].values

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        return torch.tensor(text, dtype=torch.long), torch.tensor(label, dtype=torch.long)

train_dataset = SentimentDataset(train_data)
test_dataset = SentimentDataset(test_data)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# %%
class SentimentRNN(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, output_size):
        super(SentimentRNN, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.rnn = nn.RNN(embed_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.embedding(x)
        h0 = torch.zeros(1, x.size(0), hidden_size).to(x.device)
        out, _ = self.rnn(x, h0)
        out = self.fc(out[:, -1, :])
        return out

vocab_size = len(vocab) + 1
embed_size = 24
hidden_size = 24
output_size = 2
model = SentimentRNN(vocab_size, embed_size, hidden_size, output_size)

# %%
from tqdm.auto import tqdm
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

num_epochs = 3
for epoch in tqdm(range(num_epochs)):
    model.train()
    epoch_loss = 0
    for texts, labels in tqdm(train_loader):

        outputs = model(texts)

        loss = criterion(outputs, labels)

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()

        epoch_loss += loss.item()

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss / len(train_loader):.4f}')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]

# %%
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for texts, labels in tqdm(test_loader):
        outputs = model(texts)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy: {accuracy:.2f}%')
# Out:
#   0%|          | 0/1250 [00:00<?, ?it/s]
# Accuracy: 50.39%
